# %%
import pandas as pd

# %% [markdown]
# 데이터는 2가지입니다.
#
# 1. dacon 데이터(긴급재난지원금,국토연구원 제공) 2. Localdata-지방행정인허가데이터(개폐업정보)

# %% [markdown]
# # 1. Dacon 데이터 (긴급재난지원금)
# 자료출처 :https://www.dacon.io/competitions/official/235682/data/
#
#
# data5,6,7,8은 차례로 5,6,7,8월 통계.

# %% [markdown]
# ### 데이터 정의(국토연구원 제공)

# %%
from IPython.display import Image
Image(filename = "데이터 정의.png")

# %%
#data5
df2 = pd.read_table('KRI-DAC_Jeju_data5.txt', sep =',')

# %%
df2
# Out:
#         OBJECTID  Field1      YM     SIDO SIGUNGU FranClass   Type Time  \
# 0              1       1  202005  제주특별자치도     제주시        영세   일반한식  00시
# 1              2       2  202005  제주특별자치도     제주시        영세   단란주점  00시
# 2              3       3  202005  제주특별자치도     제주시       중소1    편의점  00시
# 3              4       4  202005  제주특별자치도     제주시        영세    편의점  00시
# 4              5       5  202005  제주특별자치도     제주시        영세     주점  00시
# ...          ...     ...     ...      ...     ...       ...    ...  ...
# 273178    273179  273179  202005  제주특별자치도     제주시        중소  침구수예점   x시
# 273179    273180  273180  202005  제주특별자치도     제주시       중소1   서양음식   x시
# 273180    273181  273181  202005  제주특별자치도     제주시        영세    편의점   x시
# 273181    273182  273182  202005  제주특별자치도     제주시        중소    제과점   x시
# 273182    273183  273183  202005  제주특별자치도     제주시        영세   서양음식   x시
#
#         TotalSpent  DisSpent  NumofSpent  NumofDisSpent      POINT_X  \
# ...

# %%
#data6 , 6월 데이터
df3 = pd.read_table('KRI-DAC_Jeju_data6.txt', sep =',')

# %%
df3.head()
# Out:
#    OBJECTID  Field1      YM     SIDO SIGUNGU FranClass  Type Time  TotalSpent  \
# 0         1       1  202006  제주특별자치도     제주시        영세  일반한식  00시      502000
# 1         2       2  202006  제주특별자치도     제주시        영세  단란주점  00시     1520000
# 2         3       3  202006  제주특별자치도     제주시       중소1   편의점  00시      482310
# 3         4       4  202006  제주특별자치도     제주시        영세   편의점  00시       38050
# 4         5       5  202006  제주특별자치도     제주시        영세  일반한식  00시       32000
#
#    DisSpent  NumofSpent  NumofDisSpent      POINT_X       POINT_Y
# 0         0          10              0  877005.9834  1.479766e+06
# 1         0           8              0  877005.7447  1.479816e+06
# 2         0          35              0  877056.6756  1.479616e+06
# 3      5450           3              1  877055.9593  1.479766e+06
# 4     32000           1              1  877055.4817  1.479866e+06

# %%
#data7  7월데이터
df4 = pd.read_table('KRI-DAC_Jeju_data7.txt', sep =',')

# %%
df4.head() #첫 5행만
# Out:
#    OBJECTID  Field1      YM     SIDO SIGUNGU       X      Y FranClass  Type  \
# 0         1       1  202007  제주특별자치도     제주시  230600  80000        영세  일반한식
# 1         2       2  202007  제주특별자치도     제주시  230600  80050        영세  단란주점
# 2         3       3  202007  제주특별자치도     제주시  230650  79850       중소1   편의점
# 3         4       4  202007  제주특별자치도     제주시  230650  80000        영세   편의점
# 4         5       5  202007  제주특별자치도     제주시  230650  80100        영세    주점
#
#   Time  TotalSpent  DisSpent  NumofSpent  NumofDisSpent      POINT_X  \
# 0  00시       85500         0           4              0  877005.9834
# 1  00시     1960000         0           4              0  877005.7447
# 2  00시      475650         0          43              0  877056.6756
# 3  00시       15650         0           1              0  877055.9593
# 4  00시       82500         0           1              0  877055.4817
#
#         POINT_Y
# 0  1.479766e+06
# 1  1.479816e+06
# 2  1.479616e+06
# 3  1.479766e+06
# ...

# %%
#data8  8월 데이터
df5 = pd.read_table('KRI-DAC_Jeju_data8.txt', sep =',')

# %%
df5.head() #첫 5행만
# Out:
#    OBJECTID  Field1      YM     SIDO SIGUNGU FranClass  Type Time  TotalSpent  \
# 0         1       1  202008  제주특별자치도     제주시        영세  일반한식  00시      249500
# 1         2       2  202008  제주특별자치도     제주시        영세  단란주점  00시     2010000
# 2         3       3  202008  제주특별자치도     제주시       중소1   편의점  00시      401210
# 3         4       4  202008  제주특별자치도     제주시        영세   편의점  00시       12250
# 4         5       5  202008  제주특별자치도     제주시        영세    주점  00시       33000
#
#    DisSpent  NumofSpent  NumofDisSpent      POINT_X       POINT_Y
# 0         0           7              0  877005.9834  1.479766e+06
# 1         0           7              0  877005.7447  1.479816e+06
# 2         0          41              0  877056.6756  1.479616e+06
# 3         0           1              0  877055.9593  1.479766e+06
# 4         0           1              0  877055.4817  1.479866e+06

# %% [markdown]
# # 2. Local Data
# 자료출처 : https://www.localdata.go.kr/devcenter/dataDown.do?menuNo=20001
#
# 일단 많은 데이터 중 '개방서비스명' column이 '일반음식점','휴게음식점'인 데이터만 들고왔습니다. 이외에도 '단란주점', '유흥식당', '제과점영업' 등 다양한 데이터가 있어서 소상공인에 해당하는, 그리고 위의 1번 데이터와 겹칠 것이라 예상되는 데이터만 들고오려합니다.

# %%
df11 = pd.read_excel('6500000_제주특별자치도_07_24_04_P_일반음식점.xlsx', usecols="A, B, F, K, L, V, Z, AA, AB")

# %%
df11
# Out:
#           번호 개방서비스명     인허가일자 상세영업상태명        폐업일자         사업장명     업태구분명  \
# 0          1  일반음식점  20181129      영업         NaN         카페송키        기타
# 1          2  일반음식점  20181227      영업         NaN  그림책방앤카페노란우산        기타
# 2          3  일반음식점  20181102      영업         NaN     에릭스에스프레소        기타
# 3          4  일반음식점  20190107      영업         NaN     일품순두부한림점        한식
# 4          5  일반음식점  20190107      영업         NaN     팔도실비집아라점  식육(숯불구이)
# ...      ...    ...       ...     ...         ...          ...       ...
# 31930  31931  일반음식점  20201215      폐업  20210114.0          한라홀       경양식
# 31931  31932  일반음식점  20201202      폐업  20210111.0           98        한식
# 31932  31933  일반음식점  20201217      폐업  20201231.0     모레기동타잔돌집        한식
# 31933  31934  일반음식점  20210129      폐업  20210218.0         대정숯불        한식
# 31934  31935  일반음식점  20210120      폐업  20210216.0    한라산 봉 도야지        한식
#
#              좌표정보(X)       좌표정보(Y)
# 0      155346.157881   2179.442681
# ...

# %%
df12 = pd.read_excel('6500000_제주특별자치도_07_24_05_P_휴게음식점.xlsx', usecols="A, B, F, K, L, V, Z, AA, AB")

# %%
df12
# Out:
#         번호 개방서비스명     인허가일자 상세영업상태명        폐업일자         사업장명     업태구분명  \
# 0        1  휴게음식점  20161128      영업         NaN  스타벅스제주애월DT점       커피숍
# 1        2  휴게음식점  20200803      영업         NaN       블리스플라워  기타 휴게음식점
# 2        3  휴게음식점  20200803      영업         NaN           구룸  기타 휴게음식점
# 3        4  휴게음식점  20181122      영업         NaN           미르  기타 휴게음식점
# 4        5  휴게음식점  20181102      영업         NaN      수눌음반찬가게  기타 휴게음식점
# ...    ...    ...       ...     ...         ...          ...       ...
# 9731  9732  휴게음식점  20181128      폐업  20200605.0         메모리아       커피숍
# 9732  9733  휴게음식점  20181231      폐업  20210115.0        쥬드플뢰르       커피숍
# 9733  9734  휴게음식점  20181214      폐업  20201130.0        커피전문점      푸드트럭
# 9734  9735  휴게음식점  20181112      폐업  20201031.0      아름다운서귀포      푸드트럭
# 9735  9736  휴게음식점  20181123      폐업  20201202.0       붕어빵과오뎅  기타 휴게음식점
#
#             좌표정보(X)       좌표정보(Y)
# 0     139384.513744  -2430.084426
# 1     157441.463254   -474.495811
# ...
